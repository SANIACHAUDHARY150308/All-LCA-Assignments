# %%
my_dict={"name":"jiya","roll number": 15,"branch":"CSE","age":20,"university":"MIT-WPU"}
print("student Information:")
print(my_dict)

my_dict["email"]="jiya@123gmail.com"
print("After adding email:")
print(my_dict)

del my_dict["age"]
print ("After deleting age")
print(my_dict)
# Out:
# student Information:
# {'name': 'jiya', 'roll number': 15, 'branch': 'CSE', 'age': 20, 'university': 'MIT-WPU'}
# After adding email:
# {'name': 'jiya', 'roll number': 15, 'branch': 'CSE', 'age': 20, 'university': 'MIT-WPU', 'email': 'jiya@123gmail.com'}
# After deleting age
# {'name': 'jiya', 'roll number': 15, 'branch': 'CSE', 'university': 'MIT-WPU', 'email': 'jiya@123gmail.com'}

# %%
list1=['name','roll number','branch','age','university']
list2=['jiya','15','CSE','20','MIT-WPU']
my_dict=dict(zip(list1,list2))
print(my_dict)
# Out:
# {'name': 'jiya', 'roll number': '15', 'branch': 'CSE', 'age': '20', 'university': 'MIT-WPU'}

# %%
my_dict={'name':'jiya','roll number': '15','branch':'CSE','age':'20','university':'MIT-WPU'}
sorted(my_dict)
# Out:
# ['age', 'branch', 'name', 'roll number', 'university']

# %%
my_dict={'name':'jiya','roll number': '15','branch':'CSE','age':'20','university':'MIT-WPU'}
keys_list= list(my_dict)
print(list1) #['name','roll number','branch','age','university']
list2=list(my_dict.values())
print(list2)#['jiya','15','CSE','20','MIT-WPU']
# Out:
# ['name', 'roll number', 'branch', 'age', 'university']
# ['jiya', '15', 'CSE', '20', 'MIT-WPU']

# %%
marks={"math":85,"physics":82,"chemistry":87}
mean=sum(marks.values())/len(marks)
print(mean)
# Out:
# 84.66666666666667

# %%
my_dict={'name':['Yash','Neel','Dev'],'roll number':[11,12,13],'marks':[78,56,98]}
print(my_dict['name'][2])
print(my_dict['roll number'][1])
print(max(my_dict['marks']))
# Out:
# Dev
# 12
# 98

# %%
text=input("Enter a string:")
freq={}
for char in text:
 if char in freq:
  freq[char]=freq[char]+1
 else:
  freq[char]=1
print(freq)
# Out:
# Enter a string: Sania
# {'S': 1, 'a': 2, 'n': 1, 'i': 1}

# %%
numerator=int(input("Enter numerator:"))
denominator=int(input("Enter denominator:"))
quotient=numerator // denominator
remainder=numerator % denominator
result= (quotient,remainder)
print(result)
# Out:
# Enter numerator: 12
# Enter denominator: 5
# (2, 2)

# %%
from datetime import date 
#input first date
d1=int(input("Enter day of first date"))
m1=int(input("Enter month of first date"))
y1=int(input("Enter year of first date"))
#input second date
d2=int(input("Enter day of second date"))
m2=int(input("Enter month of second date"))
y2=int(input("Enter year of second date"))
# create date tuples
date1=(d1,m1,y1)
date2=(d2,m2,y2)
#convert tuples into date objects
date_1 = date(y1,m1,d1)
date_2 = date(y2,m2,d2)
#calculate difference
day = abs((date_2-date_1).days)
print("First date:",date_1)
print("Second date:",date_2)
print("Number of days between the two dates:",day)
# Out:
# Enter day of first date 15
# Enter month of first date 3
# Enter year of first date 2026
# Enter day of second date 30
# Enter month of second date 3
# Enter year of second date 2026
# First date: 2026-03-15
# Second date: 2026-03-30
# Number of days between the two dates: 15
