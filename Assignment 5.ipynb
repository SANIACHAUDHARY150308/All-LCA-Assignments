# %%
string=input("Enter a string")
for ch in string:
    if('a'<=ch<='z') or ('A'<=ch<='Z') or ('0'<=ch<='9'):
        continue
    else:
        print ("Invalid string")
        break 
else:
     print("Valid String")
